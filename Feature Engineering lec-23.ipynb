# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 150424.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 151056.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 151121.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 151230.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 151442.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 151647.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 151947.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load and display the image
image_path = r"C:\Users\HP\Pictures\Screenshots\Screenshot 2025-02-19 152217.png"

img = mpimg.imread(image_path)

# Show the image
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()
