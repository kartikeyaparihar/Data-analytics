# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Spotify Most Streamed Songs.csv')
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %% [markdown]
# # opening a csv file from a url

# %%
import requests
from io import StringIO

url = "http://www2.informatik.uni-freiburg.de/~cziegler/BX/"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#   <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# 0                                       <html><head>
# 1                       <title>404 Not Found</title>
# 2                                      </head><body>
# 3                                 <h1>Not Found</h1>
# 4  <p>The requested URL was not found on this ser...
# 5                                     </body></html>

# %% [markdown]
# # SEP parameter

# %%
df=pd.read_csv('file.tsv',sep='\t')
df
# Out:
#           0    50  5  881250949
# 0         0   172  5  881250949
# 1         0   133  1  881250949
# 2       196   242  3  881250949
# 3       186   302  3  891717742
# 4        22   377  1  878887116
# ...     ...   ... ..        ...
# 99997   880   476  3  880175444
# 99998   716   204  5  879795543
# 99999   276  1090  1  874795795
# 100000   13   225  2  882399156
# 100001   12   203  3  879959583
#
# [100002 rows x 4 columns]

# %% [markdown]
# # names se agr data ke coloums ka name na hoto apn add kr skte h

# %%
pd.read_csv('file.tsv',sep='\t',names=['sno','total_count','count','phn_no'])
# Out:
#         sno  total_count  count     phn_no
# 0         0           50      5  881250949
# 1         0          172      5  881250949
# 2         0          133      1  881250949
# 3       196          242      3  881250949
# 4       186          302      3  891717742
# ...     ...          ...    ...        ...
# 99998   880          476      3  880175444
# 99999   716          204      5  879795543
# 100000  276         1090      1  874795795
# 100001   13          225      2  882399156
# 100002   12          203      3  879959583
#
# [100003 rows x 4 columns]

# %% [markdown]
# # index_col parameter**

# %%
pd.read_csv('Spotify Most Streamed Songs.csv',index_col='track_name')
# Out:
#                                          artist(s)_name  artist_count  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# LALA                                        Myke Towers             1
# vampire                                  Olivia Rodrigo             1
# Cruel Summer                               Taylor Swift             1
# WHERE SHE GOES                                Bad Bunny             1
# ...                                                 ...           ...
# My Mind & Me                               Selena Gomez             1
# Bigger Than The Whole Sky                  Taylor Swift             1
# A Veces (feat. Feid)                 Feid, Paulo Londra             2
# En La De Ella                        Feid, Sech, Jhayco             3
# Alone                                         Burna Boy             1
#
#                                      released_year  released_month  \
# track_name
# ...

# %% [markdown]
# # HEADER PARAMETER**

# %%
pd.read_csv('Spotify Most Streamed Songs.csv',header=1)
# Out:
#     Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook  2  2023   7  14  \
# 0                                  LALA         Myke Towers  1  2023   3  23
# 1                               vampire      Olivia Rodrigo  1  2023   6  30
# 2                          Cruel Summer        Taylor Swift  1  2019   8  23
# 3                        WHERE SHE GOES           Bad Bunny  1  2023   5  18
# 4                              Sprinter   Dave, Central Cee  2  2023   6   1
# ..                                  ...                 ... ..   ...  ..  ..
# 947                        My Mind & Me        Selena Gomez  1  2022  11   3
# 948           Bigger Than The Whole Sky        Taylor Swift  1  2022  10  21
# 949                A Veces (feat. Feid)  Feid, Paulo Londra  2  2022  11   3
# 950                       En La De Ella  Feid, Sech, Jhayco  3  2022  10  20
# 951                               Alone           Burna Boy  1  2022  11   4
#
# ...

# %% [markdown]
# # **USE_COLS PARAMETER**

# %%
pd.read_csv('Spotify Most Streamed Songs.csv',usecols=['artist(s)_name','artist_count','released_year','released_month'])
# Out:
#          artist(s)_name  artist_count  released_year  released_month
# 0      Latto, Jung Kook             2           2023               7
# 1           Myke Towers             1           2023               3
# 2        Olivia Rodrigo             1           2023               6
# 3          Taylor Swift             1           2019               8
# 4             Bad Bunny             1           2023               5
# ..                  ...           ...            ...             ...
# 948        Selena Gomez             1           2022              11
# 949        Taylor Swift             1           2022              10
# 950  Feid, Paulo Londra             2           2022              11
# 951  Feid, Sech, Jhayco             3           2022              10
# 952           Burna Boy             1           2022              11
#
# [953 rows x 4 columns]

# %% [markdown]
# # **SQUEEZE PARAMETER**data frame na banke pd series ban jata h

# %%
pd.read_csv('Spotify Most Streamed Songs.csv',usecols=['artist(s)_name'],squeeze=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.read_csv('Spotify Most Streamed Songs.csv',usecols=['artist(s)_name'],squeeze=True)
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %% [markdown]
# **SKIP_ROWS PARAMETER**

# %%
pd.read_csv('Spotify Most Streamed Songs.csv',skiprows=[0,1])
# Out:
#                           LALA                 Myke Towers  1  2023   3  23  \
# 0                      vampire              Olivia Rodrigo  1  2023   6  30
# 1                 Cruel Summer                Taylor Swift  1  2019   8  23
# 2               WHERE SHE GOES                   Bad Bunny  1  2023   5  18
# 3                     Sprinter           Dave, Central Cee  2  2023   6   1
# 4              Ella Baila Sola  Eslabon Armado, Peso Pluma  2  2023   3  16
# ..                         ...                         ... ..   ...  ..  ..
# 946               My Mind & Me                Selena Gomez  1  2022  11   3
# 947  Bigger Than The Whole Sky                Taylor Swift  1  2022  10  21
# 948       A Veces (feat. Feid)          Feid, Paulo Londra  2  2022  11   3
# 949              En La De Ella          Feid, Sech, Jhayco  3  2022  10  20
# 950                      Alone                   Burna Boy  1  2022  11   4
#
# ...

# %%
pd.read_csv('Spotify Most Streamed Songs.csv',nrows=100)
# Out:
#                              track_name     artist(s)_name  artist_count  \
# 0   Seven (feat. Latto) (Explicit Ver.)   Latto, Jung Kook             2
# 1                                  LALA        Myke Towers             1
# 2                               vampire     Olivia Rodrigo             1
# 3                          Cruel Summer       Taylor Swift             1
# 4                        WHERE SHE GOES          Bad Bunny             1
# ..                                  ...                ...           ...
# 95          All My Life (feat. J. Cole)  J. Cole, Lil Durk             2
# 96                    Say Yes To Heaven       Lana Del Rey             1
# 97                               Snooze                SZA             1
# 98                   Summertime Sadness       Lana Del Rey             1
# 99                             Take Two                BTS             1
#
#     released_year  released_month  released_day  in_spotify_playlists  \
# ...

# %% [markdown]
# # **SKIP BADLINES agar PARSEERROR NAAM KA ERROR AARA HETO YE PARAMETER TRY KRLENA**

# %%
pd.read_csv('BX-Books.csv', sep=';', encoding="latin-1",error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 pd.read_csv('BX-Books.csv', sep=';', encoding="latin-1",error_bad_lines=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'

# %% [markdown]
# # **dtypes parameter info() se kis column ka kya data type h vo pata chl jata h or isme apn ne target naam ke coloumn ko float values se int banaya h**

# %%
pd.read_csv('aug_train.csv',dtype={'target':int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int32
# ...

# %% [markdown]
# # **HANDLING DATES pandas me object ka mtlb string hota h**

# %%
pd.read_csv('IPL Matches 2008-2020.csv')
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
pd.read_csv('IPL Matches 2008-2020.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
pd.read_csv('IPL Matches 2008-2020.csv',parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
pd.read_csv('IPL Matches 2008-2020.csv')
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # **output me change ni ayega pr uski inter setting badal gyi h now we can perform operatins on date**

# %% [raw]
# list of int or names. e.g. If [1, 2, 3] -> try parsing columns 1, 2, 3 each as a separate date column.
#
# list of list. e.g. If [[1, 3]] -> combine columns 1 and 3 and parse as a single date column. Values are joined with a space before parsing.
#
# dict, e.g. {'foo' : [1, 3]} -> parse columns 1, 3 as date and call result ‘foo’. Values are joined with a space before parsing.

# %% [markdown]
# # **CONVERTERS**

# %%
pd.read_csv('IPL Matches 2008-2020.csv')
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name

# %%
rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %%
pd.read_csv('IPL Matches 2008-2020.csv')
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
pd.read_csv('IPL Matches 2008-2020.csv',converters={'team1':rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # **NA_VALUES PARAMETER**

# %%
pd.read_csv('aug_train.csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
pd.read_csv('aug_train.csv',na_values=['Male',])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# # **LOADING HUGE DATASETS IN CHUNKS**

# %%
dfs = pd.read_csv('aug_train.csv',chunksize=5000)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
